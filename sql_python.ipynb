# %%
import mysql.connector

db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "9899"

)

print("Connection Successful" if db.is_connected() else "Connection Failed.")

# %%
test_cursor = db.cursor()
test_cursor.execute("SHOW DATABASES")
for i in test_cursor:
    print(i)

# %%
test_cursor.execute("DROP DATABASE IF EXISTS job_applications")

# %%
test_cursor.execute("CREATE DATABASE job_applications")

# %%
test_cursor.execute("USE job_applications")

# %%
test_cursor.execute("DROP TABLE IF EXISTS applications")

# %%
test_cursor.execute("""CREATE TABLE applications(
                    date DATE, 
                    company VARCHAR(50),
                    role VARCHAR(50),
                    location varchar(50), 
                    salary_quoted INT,
                    status ENUM( "applied", "rejected","waiting"))""")

# %%
test_cursor.execute("""
                    INSERT INTO applications(date,company,role,location,salary_quoted,status)
                    VALUES('2016-03-09', 'intigrityfactor', 'data_analyst_trainee', 'bangalore', 500000, 'applied' )
                    """)

# %%
test_cursor.execute("SELECT * FROM applications")
a = test_cursor.fetchall()
for i in a:
    print(i)

# %%
import mysql.connector

try: 

    db = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = '9899',
        database = 'sakila'
    )

    if db.connect(): 
        print("Connection status : Success")

except mysql.connector.Error as error: 
    print("Connection satus :Failed")

# %%
test_cursor = db.cursor()

test_cursor.execute("SHOW TABLES")
for i in test_cursor:
    print(i)

# %%
import mysql.connector

db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "9899",
    database = "sakila"
)

cr = db.cursor()

queries = ["DESCRIBE language", "DESCRIBE rental"]

for q in queries:
    cr.execute(q)
    print(f"\nThe result of {q}:")

    for row in cr.fetchall():
        print(row)

# %%
import mysql.connector
from tabulate import tabulate

db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "9899",
    database = "sakila"
)

cr = db.cursor()

cr.execute("""
           SELECT * FROM store s 
           INNER JOIN inventory i
           ON s.store_id  = i.store_id
           INNER JOIN film_text ft
           ON ft.film_id = i.film_id
           """)

rows = cr.fetchall()
columns = [col[0] for col in cr.description]

print(tabulate(rows, headers = columns, tablefmt = "grid"))
# Out:
# +------------+--------------------+--------------+---------------------+----------------+-----------+------------+---------------------+-----------+-----------------------------+------------------------------------------------------------------------------------------------------------------------------------+
# |   store_id |   manager_staff_id |   address_id | last_update         |   inventory_id |   film_id |   store_id | last_update         |   film_id | title                       | description                                                                                                                        |
# +============+====================+==============+=====================+================+===========+============+=====================+===========+=============================+====================================================================================================================================+
# ...

# %%
import mysql.connector
from tabulate import tabulate
database = "alumni"

try:

    df = mysql.connector.connect(
        host = "localhost",
        user = "root",
        password = "9899",
        database = database
    )

    if df.is_connected():
        print(f"The connection to {database} was successful.")

except mysql.connector.error as Error:
    print(f"The connection to {database} was failed.")


cr = df.cursor()

cr.execute("SELECT COUNT(*) FROM college_a_hs")

rows = cr.fetchall()
columns = [col[0] for col in cr.description]

print(f"{tabulate(rows[:1000], headers = columns, tablefmt = "grid")}")
# Out:
# The connection to alumni was successful.
# +------------+
# |   COUNT(*) |
# +============+
# |       1157 |
# +------------+
